# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %% [markdown]
# ## copy

# %%
df_copy = df.copy() # 원본은 그대로 두고 복사본을 새로 만듦

# %%
id(df_copy), id(df)
# Out:
# (1890639986768, 1890639073104)

# %%
df_copy.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_copy.loc[0, 'age'] = 99999

# %%
df_copy.head(1)
# Out:
#    survived  pclass   sex      age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  99999.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
df.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %% [markdown]
# ## 결측치
# 1. 결측 데이터 **확인**
# 2. 결측치가 아닌 데이터 **확인**
# ---------------
# 1. 결측치 채우기
# 2. 결측 데이터 제거하기

# %%
df_copy = df.copy()

# %%
df_copy.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_copy.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_copy.notnull().sum() # 비어있지 않은 것 출력
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %% [markdown]
# ## 결측 데이터 필터링

# %%
# 결측 데이터를 골라봄
cond = df_copy['age'].isnull()
df_copy.loc[cond, 'age']  = 30

# %%
df_copy.tail() # 888번이 아까 비어져있었는데 지금은 30살로 출력이 돼있음
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  30.0      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# ## fillna()

# %%
df_copy = df.copy()

# %%
df_copy.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df_copy['age'].fillna(100) # 위에서 한 거를 한번에 처리
# Out:
# 0       22.0
# 1       38.0
# 2       26.0
# 3       35.0
# 4       35.0
#        ...
# 886     27.0
# 887     19.0
# 888    100.0
# 889     26.0
# 890     32.0
# Name: age, Length: 891, dtype: float64

# %%
df_copy.tail() # 직접적으로 수정하지는 않고 연산결과만 보여줌
# 만약 원본파일도 수정하고 싶으면
# df_copy['age']= df_copy['age'].fillna(100) 로 재할당을 해줘야 함
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df_copy['deck'].value_counts()
# Out:
# deck
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
df_copy['deck'].fillna('C')
# Out:
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C
#       ..
# 886    C
# 887    B
# 888    C
# 889    C
# 890    C
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df_copy['deck'].fillna('Z') # 카테고리에 없는 Z로는 불가능 카테고리 안에 있는 값들만 가능
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df_copy['deck'].fillna('Z') # 카테고리에 없는 Z로는 불가능 카테고리 안에 있는 값들만 가능
#
# File ~\Desktop\DAMF\pandas\venv\Lib\site-packages\pandas\core\generic.py:7349, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7342     else:
#    7343         raise TypeError(
#    7344             '"value" parameter must be a scalar, dict '
#    7345             "or Series, but you passed a "
#    7346             f'"{type(value).__name__}"'
#    7347         )
# -> 7349     new_data = self._mgr.fillna(
#    7350         value=value, limit=limit, inplace=inplace, downcast=downcast
#    7351     )
#    7353 elif isinstance(value, (dict, ABCSeries)):
#    7354     if axis == 1:
#
# ...

# %%
df_copy['deck'] = df_copy['deck'].cat.add_categories('Z') # cat = categorie 카테고리에 Z먼저 추가하기
df_copy['deck'].fillna('Z') # 비어있는 공간에 Z 입력
# Out:
# 0      Z
# 1      C
# 2      Z
# 3      C
# 4      Z
#       ..
# 886    Z
# 887    B
# 888    Z
# 889    C
# 890    Z
# Name: deck, Length: 891, dtype: category
# Categories (8, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'Z']

# %%
age_mean = df_copy['age'].mean()

# %%
df_copy['age'] = df_copy['age'].fillna(age_mean)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_copy = df.copy()

# %%
df_copy['age'] = df_copy['age'].fillna(df_copy['age'].median())

# %%
df_copy.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  28.0      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# ## practice
# - 남자 승객의 결측치는 남자 승객의 평균
# - 여자 승객의 결측치는 여자 승객의 평균
# - 결측치를 모두 채우고 나서 모든 사람의 평균

# %%
df_copy = df.copy()

# %%
# 남자 승객의 결측치 모으기
# 우선 남자 승객의 정보만 모으기

cond1 = df_copy['sex'] == 'male' 
male_mean = df_copy.loc[cond1, 'age'].mean()
print(male_mean)

# df_man = df_copy[cond1]
# df_man.isnull().sum()

# # age_mean = df_copy['age'].mean()
# # df_copy['age'] = df_copy['age'].fillna(age_mean)
# man_age_mean = df_man['age'].mean()
# man_deck_mean = df_man['deck'].mean()

# df_man['age'] = df_man['age'].fillna(man_age_mean)
# df_man['deck'] = df_man['deck'].fillna(man_deck_mean)
# Out:
# 30.726644591611475

# %%
cond2 = df_copy['sex'] == 'female'
female_mean = df_copy.loc[cond2, 'age'].mean()
print(female_mean)
# Out:
# 27.915708812260537

# %%
df_copy.loc[cond1, 'age'] = df_copy.loc[cond1, 'age'].fillna(male_mean)
df_copy.loc[cond2, 'age'] = df_copy.loc[cond2, 'age'].fillna(female_mean)

# %%
df_copy['age'].mean()
# Out:
# np.float64(29.736034227171306)

# %% [markdown]
# ## dropna()

# %%
df_copy =  df.copy()

# %%
df_copy.dropna() # na값이 있는것은 다 지워줌
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_copy.dropna(how='all') # 모두 다 na값이 있는 것들만 지워줌
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
